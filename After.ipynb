# %%
import numpy as np
import cv2

from scipy import ndimage, misc
import os, glob
import sys
import skimage
from skimage import feature, data, io

from scipy.misc import imread, imsave
from PIL import Image
import random
# Out:
# /home/sara/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/sara/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/sara/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/sara/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   return f(*args, **kwds)

# %%
def get_file_name_dir(rootDir, ext):
 
    # Return file names with certain extension

    return glob.glob1(rootDir, "*." + ext)



def HorizontalFlip(img):
    prob=0.5
    if random.random() < prob:
        img = cv2.flip(img, 1)
    return img


def VerticalFlip(img):
    prob=0.5
    if random.random() < prob:
        img = cv2.flip(img, 0)
    return img

# %%
"""
Get name images to preprocessing
--------------------------------
"""
input_path = 'data/instrument_dataset_9/augmented/images/'
input_extension = 'png'

inputs_files = sorted(get_file_name_dir(input_path, input_extension))

print(('**')*30)
print('********************* Preprocessing *************************')
print(('**')*30)

"""
Iterate over the list of images
-------------------------------
"""
cont = 1

for file_name in inputs_files:
    print('Preprocessing: ' + file_name + ': ' + str(cont))
    cont += 1
    # Get the image
    img = input_path + file_name
    im_in = cv2.imread(img, cv2.IMREAD_GRAYSCALE)

    # Crop Image
    image = VerticalFlip(im_in)
#     image = Image.fromarray(image)
     # Save Image
    cv2.imwrite('data/instrument_dataset_9/augmented/images/' + 'VF_' +file_name , image)
# Out:
# ************************************************************
# ********************* Preprocessing *************************
# ************************************************************
# Preprocessing: 630_2HC.png: 1
# Preprocessing: 630_HC.png: 2
# Preprocessing: 631_2HC.png: 3
# Preprocessing: 631_HC.png: 4
# Preprocessing: 632_HC.png: 5
# Preprocessing: 633_HC.png: 6
# Preprocessing: 634_HC.png: 7
# Preprocessing: 635_HC.png: 8
# Preprocessing: 636_HC.png: 9
# Preprocessing: 637_HC.png: 10
# Preprocessing: 638_HC.png: 11
# Preprocessing: 639_2HC.png: 12
# Preprocessing: 639_HC.png: 13
# Preprocessing: 640_HC.png: 14
# Preprocessing: 641_HC.png: 15
# Preprocessing: 642_HC.png: 16
# Preprocessing: 643_HC.png: 17
# Preprocessing: 644_HC.png: 18
# Preprocessing: 645_HC.png: 19
# Preprocessing: 646_HC.png: 20
# Preprocessing: 647_HC.png: 21
# Preprocessing: 648_2HC.png: 22
# Preprocessing: 648_HC.png: 23
# Preprocessing: 649_HC.png: 24
# Preprocessing: 650_HC.png: 25
# Preprocessing: 651_HC.png: 26
# Preprocessing: 652_2HC.png: 27
# Preprocessing: 652_HC.png: 28
# Preprocessing: 653_HC.png: 29
# Preprocessing: 654_HC.png: 30
# Preprocessing: 655_HC.png: 31
# Preprocessing: 656_HC.png: 32
# Preprocessing: 657_2HC.png: 33
# Preprocessing: 657_HC.png: 34
# Preprocessing: 658_HC.png: 35
# Preprocessing: 659_HC.png: 36
# Preprocessing: 660_HC.png: 37
# Preprocessing: 661_HC.png: 38
# Preprocessing: 662_HC.png: 39
# Preprocessing: 663_HC.png: 40
# Preprocessing: 664_HC.png: 41
# Preprocessing: 665_HC.png: 42
# Preprocessing: 666_HC.png: 43
# Preprocessing: 667_HC.png: 44
# Preprocessing: 668_HC.png: 45
# Preprocessing: 669_HC.png: 46
# Preprocessing: 670_HC.png: 47
# Preprocessing: 671_2HC.png: 48
# Preprocessing: 671_3HC.png: 49
# Preprocessing: 671_HC.png: 50
# Preprocessing: 672_HC.png: 51
# Preprocessing: 673_2HC.png: 52
# Preprocessing: 673_HC.png: 53
# Preprocessing: 674_HC.png: 54
# Preprocessing: 675_2HC.png: 55
# Preprocessing: 675_HC.png: 56
# Preprocessing: 676_HC.png: 57
# Preprocessing: 677_2HC.png: 58
# Preprocessing: 677_HC.png: 59
# Preprocessing: 678_HC.png: 60
# Preprocessing: 679_HC.png: 61
# Preprocessing: 680_HC.png: 62
# Preprocessing: 681_HC.png: 63
# Preprocessing: 682_HC.png: 64
# Preprocessing: 683_HC.png: 65
# Preprocessing: 684_HC.png: 66
# Preprocessing: 685_HC.png: 67
# Preprocessing: 686_2HC.png: 68
# Preprocessing: 686_HC.png: 69
# Preprocessing: 687_HC.png: 70
# Preprocessing: 688_HC.png: 71
# Preprocessing: 689_HC.png: 72
# Preprocessing: 690_2HC.png: 73
# Preprocessing: 690_HC.png: 74
# Preprocessing: 691_HC.png: 75
# Preprocessing: 692_2HC.png: 76
# Preprocessing: 692_HC.png: 77
# Preprocessing: 693_HC.png: 78
# Preprocessing: 694_HC.png: 79
# Preprocessing: 695_HC.png: 80
# Preprocessing: 696_HC.png: 81
# Preprocessing: 697_HC.png: 82
# Preprocessing: 698_HC.png: 83
# Preprocessing: 699_HC.png: 84
# Preprocessing: 700_HC.png: 85
# Preprocessing: 701_HC.png: 86
# Preprocessing: 702_HC.png: 87
# Preprocessing: 703_HC.png: 88
# Preprocessing: 704_2HC.png: 89
# Preprocessing: 704_HC.png: 90
# Preprocessing: 705_HC.png: 91
# Preprocessing: 706_HC.png: 92
# Preprocessing: 707_HC.png: 93
# Preprocessing: 708_2HC.png: 94
# Preprocessing: 708_3HC.png: 95
# Preprocessing: 708_HC.png: 96
# Preprocessing: 709_2HC.png: 97
# Preprocessing: 709_HC.png: 98
# Preprocessing: 710_HC.png: 99
# Preprocessing: 711_HC.png: 100
# Preprocessing: 712_2HC.png: 101
# Preprocessing: 712_HC.png: 102
# Preprocessing: 713_HC.png: 103
# Preprocessing: 714_HC.png: 104
# Preprocessing: 715_HC.png: 105
# Preprocessing: 716_HC.png: 106
# Preprocessing: 717_2HC.png: 107
# Preprocessing: 717_HC.png: 108
# Preprocessing: 718_2HC.png: 109
# Preprocessing: 718_HC.png: 110
# Preprocessing: 719_HC.png: 111
# Preprocessing: HF_630_2HC.png: 112
# Preprocessing: HF_630_HC.png: 113
# Preprocessing: HF_631_2HC.png: 114
# Preprocessing: HF_631_HC.png: 115
# Preprocessing: HF_632_HC.png: 116
# Preprocessing: HF_633_HC.png: 117
# Preprocessing: HF_634_HC.png: 118
# Preprocessing: HF_635_HC.png: 119
# Preprocessing: HF_636_HC.png: 120
# Preprocessing: HF_637_HC.png: 121
# Preprocessing: HF_638_HC.png: 122
# Preprocessing: HF_639_2HC.png: 123
# Preprocessing: HF_639_HC.png: 124
# Preprocessing: HF_640_HC.png: 125
# Preprocessing: HF_641_HC.png: 126
# Preprocessing: HF_642_HC.png: 127
# Preprocessing: HF_643_HC.png: 128
# Preprocessing: HF_644_HC.png: 129
# Preprocessing: HF_645_HC.png: 130
# Preprocessing: HF_646_HC.png: 131
# Preprocessing: HF_647_HC.png: 132
# Preprocessing: HF_648_2HC.png: 133
# Preprocessing: HF_648_HC.png: 134
# Preprocessing: HF_649_HC.png: 135
# Preprocessing: HF_650_HC.png: 136
# Preprocessing: HF_651_HC.png: 137
# Preprocessing: HF_652_2HC.png: 138
# Preprocessing: HF_652_HC.png: 139
# Preprocessing: HF_653_HC.png: 140
# Preprocessing: HF_654_HC.png: 141
# Preprocessing: HF_655_HC.png: 142
# Preprocessing: HF_656_HC.png: 143
# Preprocessing: HF_657_2HC.png: 144
# Preprocessing: HF_657_HC.png: 145
# Preprocessing: HF_658_HC.png: 146
# Preprocessing: HF_659_HC.png: 147
# Preprocessing: HF_660_HC.png: 148
# Preprocessing: HF_661_HC.png: 149
# Preprocessing: HF_662_HC.png: 150
# Preprocessing: HF_663_HC.png: 151
# Preprocessing: HF_664_HC.png: 152
# Preprocessing: HF_665_HC.png: 153
# Preprocessing: HF_666_HC.png: 154
# Preprocessing: HF_667_HC.png: 155
# Preprocessing: HF_668_HC.png: 156
# Preprocessing: HF_669_HC.png: 157
# Preprocessing: HF_670_HC.png: 158
# Preprocessing: HF_671_2HC.png: 159
# Preprocessing: HF_671_3HC.png: 160
# Preprocessing: HF_671_HC.png: 161
# Preprocessing: HF_672_HC.png: 162
# Preprocessing: HF_673_2HC.png: 163
# Preprocessing: HF_673_HC.png: 164
# Preprocessing: HF_674_HC.png: 165
# Preprocessing: HF_675_2HC.png: 166
# Preprocessing: HF_675_HC.png: 167
# Preprocessing: HF_676_HC.png: 168
# Preprocessing: HF_677_2HC.png: 169
# Preprocessing: HF_677_HC.png: 170
# Preprocessing: HF_678_HC.png: 171
# Preprocessing: HF_679_HC.png: 172
# Preprocessing: HF_680_HC.png: 173
# Preprocessing: HF_681_HC.png: 174
# Preprocessing: HF_682_HC.png: 175
# Preprocessing: HF_683_HC.png: 176
# Preprocessing: HF_684_HC.png: 177
# Preprocessing: HF_685_HC.png: 178
# Preprocessing: HF_686_2HC.png: 179
# Preprocessing: HF_686_HC.png: 180
# Preprocessing: HF_687_HC.png: 181
# Preprocessing: HF_688_HC.png: 182
# Preprocessing: HF_689_HC.png: 183
# Preprocessing: HF_690_2HC.png: 184
# Preprocessing: HF_690_HC.png: 185
# Preprocessing: HF_691_HC.png: 186
# Preprocessing: HF_692_2HC.png: 187
# Preprocessing: HF_692_HC.png: 188
# Preprocessing: HF_693_HC.png: 189
# Preprocessing: HF_694_HC.png: 190
# Preprocessing: HF_695_HC.png: 191
# Preprocessing: HF_696_HC.png: 192
# Preprocessing: HF_697_HC.png: 193
# Preprocessing: HF_698_HC.png: 194
# Preprocessing: HF_699_HC.png: 195
# Preprocessing: HF_700_HC.png: 196
# Preprocessing: HF_701_HC.png: 197
# Preprocessing: HF_702_HC.png: 198
# Preprocessing: HF_703_HC.png: 199
# Preprocessing: HF_704_2HC.png: 200
# Preprocessing: HF_704_HC.png: 201
# Preprocessing: HF_705_HC.png: 202
# Preprocessing: HF_706_HC.png: 203
# Preprocessing: HF_707_HC.png: 204
# Preprocessing: HF_708_2HC.png: 205
# Preprocessing: HF_708_3HC.png: 206
# Preprocessing: HF_708_HC.png: 207
# Preprocessing: HF_709_2HC.png: 208
# Preprocessing: HF_709_HC.png: 209
# Preprocessing: HF_710_HC.png: 210
# Preprocessing: HF_711_HC.png: 211
# Preprocessing: HF_712_2HC.png: 212
# Preprocessing: HF_712_HC.png: 213
# Preprocessing: HF_713_HC.png: 214
# Preprocessing: HF_714_HC.png: 215
# Preprocessing: HF_715_HC.png: 216
# Preprocessing: HF_716_HC.png: 217
# Preprocessing: HF_717_2HC.png: 218
# Preprocessing: HF_717_HC.png: 219
# Preprocessing: HF_718_2HC.png: 220
# Preprocessing: HF_718_HC.png: 221
# Preprocessing: HF_719_HC.png: 222

# %%
"""
Get name images to preprocessing
--------------------------------
"""
input_path = 'data/instrument_dataset_9/augmented/binary_masks/'
input_extension = 'png'

inputs_files = sorted(get_file_name_dir(input_path, input_extension))

print(('**')*30)
print('********************* Preprocessing *************************')
print(('**')*30)

"""
Iterate over the list of images
-------------------------------
"""
cont = 1

for file_name in inputs_files:
    print('Preprocessing: ' + file_name + ': ' + str(cont))
    cont += 1
    # Get the image
    img = input_path + file_name
    im_in = cv2.imread(img, cv2.IMREAD_GRAYSCALE)

    # Crop Image
    image = VerticalFlip(im_in)
#     image = Image.fromarray(image)
     # Save Image
    cv2.imwrite('data/instrument_dataset_9/augmented/binary_masks/' + 'VF_' +file_name , image)
# Out:
# ************************************************************
# ********************* Preprocessing *************************
# ************************************************************
# Preprocessing: 630_2HC_Annotation.png: 1
# Preprocessing: 630_HC_Annotation.png: 2
# Preprocessing: 631_2HC_Annotation.png: 3
# Preprocessing: 631_HC_Annotation.png: 4
# Preprocessing: 632_HC_Annotation.png: 5
# Preprocessing: 633_HC_Annotation.png: 6
# Preprocessing: 634_HC_Annotation.png: 7
# Preprocessing: 635_HC_Annotation.png: 8
# Preprocessing: 636_HC_Annotation.png: 9
# Preprocessing: 637_HC_Annotation.png: 10
# Preprocessing: 638_HC_Annotation.png: 11
# Preprocessing: 639_2HC_Annotation.png: 12
# Preprocessing: 639_HC_Annotation.png: 13
# Preprocessing: 640_HC_Annotation.png: 14
# Preprocessing: 641_HC_Annotation.png: 15
# Preprocessing: 642_HC_Annotation.png: 16
# Preprocessing: 643_HC_Annotation.png: 17
# Preprocessing: 644_HC_Annotation.png: 18
# Preprocessing: 645_HC_Annotation.png: 19
# Preprocessing: 646_HC_Annotation.png: 20
# Preprocessing: 647_HC_Annotation.png: 21
# Preprocessing: 648_2HC_Annotation.png: 22
# Preprocessing: 648_HC_Annotation.png: 23
# Preprocessing: 649_HC_Annotation.png: 24
# Preprocessing: 650_HC_Annotation.png: 25
# Preprocessing: 651_HC_Annotation.png: 26
# Preprocessing: 652_2HC_Annotation.png: 27
# Preprocessing: 652_HC_Annotation.png: 28
# Preprocessing: 653_HC_Annotation.png: 29
# Preprocessing: 654_HC_Annotation.png: 30
# Preprocessing: 655_HC_Annotation.png: 31
# Preprocessing: 656_HC_Annotation.png: 32
# Preprocessing: 657_2HC_Annotation.png: 33
# Preprocessing: 657_HC_Annotation.png: 34
# Preprocessing: 658_HC_Annotation.png: 35
# Preprocessing: 659_HC_Annotation.png: 36
# Preprocessing: 660_HC_Annotation.png: 37
# Preprocessing: 661_HC_Annotation.png: 38
# Preprocessing: 662_HC_Annotation.png: 39
# Preprocessing: 663_HC_Annotation.png: 40
# Preprocessing: 664_HC_Annotation.png: 41
# Preprocessing: 665_HC_Annotation.png: 42
# Preprocessing: 666_HC_Annotation.png: 43
# Preprocessing: 667_HC_Annotation.png: 44
# Preprocessing: 668_HC_Annotation.png: 45
# Preprocessing: 669_HC_Annotation.png: 46
# Preprocessing: 670_HC_Annotation.png: 47
# Preprocessing: 671_2HC_Annotation.png: 48
# Preprocessing: 671_3HC_Annotation.png: 49
# Preprocessing: 671_HC_Annotation.png: 50
# Preprocessing: 672_HC_Annotation.png: 51
# Preprocessing: 673_2HC_Annotation.png: 52
# Preprocessing: 673_HC_Annotation.png: 53
# Preprocessing: 674_HC_Annotation.png: 54
# Preprocessing: 675_2HC_Annotation.png: 55
# Preprocessing: 675_HC_Annotation.png: 56
# Preprocessing: 676_HC_Annotation.png: 57
# Preprocessing: 677_2HC_Annotation.png: 58
# Preprocessing: 677_HC_Annotation.png: 59
# Preprocessing: 678_HC_Annotation.png: 60
# Preprocessing: 679_HC_Annotation.png: 61
# Preprocessing: 680_HC_Annotation.png: 62
# Preprocessing: 681_HC_Annotation.png: 63
# Preprocessing: 682_HC_Annotation.png: 64
# Preprocessing: 683_HC_Annotation.png: 65
# Preprocessing: 684_HC_Annotation.png: 66
# Preprocessing: 685_HC_Annotation.png: 67
# Preprocessing: 686_2HC_Annotation.png: 68
# Preprocessing: 686_HC_Annotation.png: 69
# Preprocessing: 687_HC_Annotation.png: 70
# Preprocessing: 688_HC_Annotation.png: 71
# Preprocessing: 689_HC_Annotation.png: 72
# Preprocessing: 690_2HC_Annotation.png: 73
# Preprocessing: 690_HC_Annotation.png: 74
# Preprocessing: 691_HC_Annotation.png: 75
# Preprocessing: 692_2HC_Annotation.png: 76
# Preprocessing: 692_HC_Annotation.png: 77
# Preprocessing: 693_HC_Annotation.png: 78
# Preprocessing: 694_HC_Annotation.png: 79
# Preprocessing: 695_HC_Annotation.png: 80
# Preprocessing: 696_HC_Annotation.png: 81
# Preprocessing: 697_HC_Annotation.png: 82
# Preprocessing: 698_HC_Annotation.png: 83
# Preprocessing: 699_HC_Annotation.png: 84
# Preprocessing: 700_HC_Annotation.png: 85
# Preprocessing: 701_HC_Annotation.png: 86
# Preprocessing: 702_HC_Annotation.png: 87
# Preprocessing: 703_HC_Annotation.png: 88
# Preprocessing: 704_2HC_Annotation.png: 89
# Preprocessing: 704_HC_Annotation.png: 90
# Preprocessing: 705_HC_Annotation.png: 91
# Preprocessing: 706_HC_Annotation.png: 92
# Preprocessing: 707_HC_Annotation.png: 93
# Preprocessing: 708_2HC_Annotation.png: 94
# Preprocessing: 708_3HC_Annotation.png: 95
# Preprocessing: 708_HC_Annotation.png: 96
# Preprocessing: 709_2HC_Annotation.png: 97
# Preprocessing: 709_HC_Annotation.png: 98
# Preprocessing: 710_HC_Annotation.png: 99
# Preprocessing: 711_HC_Annotation.png: 100
# Preprocessing: 712_2HC_Annotation.png: 101
# Preprocessing: 712_HC_Annotation.png: 102
# Preprocessing: 713_HC_Annotation.png: 103
# Preprocessing: 714_HC_Annotation.png: 104
# Preprocessing: 715_HC_Annotation.png: 105
# Preprocessing: 716_HC_Annotation.png: 106
# Preprocessing: 717_2HC_Annotation.png: 107
# Preprocessing: 717_HC_Annotation.png: 108
# Preprocessing: 718_2HC_Annotation.png: 109
# Preprocessing: 718_HC_Annotation.png: 110
# Preprocessing: 719_HC_Annotation.png: 111
# Preprocessing: HF_630_2HC_Annotation.png: 112
# Preprocessing: HF_630_HC_Annotation.png: 113
# Preprocessing: HF_631_2HC_Annotation.png: 114
# Preprocessing: HF_631_HC_Annotation.png: 115
# Preprocessing: HF_632_HC_Annotation.png: 116
# Preprocessing: HF_633_HC_Annotation.png: 117
# Preprocessing: HF_634_HC_Annotation.png: 118
# Preprocessing: HF_635_HC_Annotation.png: 119
# Preprocessing: HF_636_HC_Annotation.png: 120
# Preprocessing: HF_637_HC_Annotation.png: 121
# Preprocessing: HF_638_HC_Annotation.png: 122
# Preprocessing: HF_639_2HC_Annotation.png: 123
# Preprocessing: HF_639_HC_Annotation.png: 124
# Preprocessing: HF_640_HC_Annotation.png: 125
# Preprocessing: HF_641_HC_Annotation.png: 126
# Preprocessing: HF_642_HC_Annotation.png: 127
# Preprocessing: HF_643_HC_Annotation.png: 128
# Preprocessing: HF_644_HC_Annotation.png: 129
# Preprocessing: HF_645_HC_Annotation.png: 130
# Preprocessing: HF_646_HC_Annotation.png: 131
# Preprocessing: HF_647_HC_Annotation.png: 132
# Preprocessing: HF_648_2HC_Annotation.png: 133
# Preprocessing: HF_648_HC_Annotation.png: 134
# Preprocessing: HF_649_HC_Annotation.png: 135
# Preprocessing: HF_650_HC_Annotation.png: 136
# Preprocessing: HF_651_HC_Annotation.png: 137
# Preprocessing: HF_652_2HC_Annotation.png: 138
# Preprocessing: HF_652_HC_Annotation.png: 139
# Preprocessing: HF_653_HC_Annotation.png: 140
# Preprocessing: HF_654_HC_Annotation.png: 141
# Preprocessing: HF_655_HC_Annotation.png: 142
# Preprocessing: HF_656_HC_Annotation.png: 143
# Preprocessing: HF_657_2HC_Annotation.png: 144
# Preprocessing: HF_657_HC_Annotation.png: 145
# Preprocessing: HF_658_HC_Annotation.png: 146
# Preprocessing: HF_659_HC_Annotation.png: 147
# Preprocessing: HF_660_HC_Annotation.png: 148
# Preprocessing: HF_661_HC_Annotation.png: 149
# Preprocessing: HF_662_HC_Annotation.png: 150
# Preprocessing: HF_663_HC_Annotation.png: 151
# Preprocessing: HF_664_HC_Annotation.png: 152
# Preprocessing: HF_665_HC_Annotation.png: 153
# Preprocessing: HF_666_HC_Annotation.png: 154
# Preprocessing: HF_667_HC_Annotation.png: 155
# Preprocessing: HF_668_HC_Annotation.png: 156
# Preprocessing: HF_669_HC_Annotation.png: 157
# Preprocessing: HF_670_HC_Annotation.png: 158
# Preprocessing: HF_671_2HC_Annotation.png: 159
# Preprocessing: HF_671_3HC_Annotation.png: 160
# Preprocessing: HF_671_HC_Annotation.png: 161
# Preprocessing: HF_672_HC_Annotation.png: 162
# Preprocessing: HF_673_2HC_Annotation.png: 163
# Preprocessing: HF_673_HC_Annotation.png: 164
# Preprocessing: HF_674_HC_Annotation.png: 165
# Preprocessing: HF_675_2HC_Annotation.png: 166
# Preprocessing: HF_675_HC_Annotation.png: 167
# Preprocessing: HF_676_HC_Annotation.png: 168
# Preprocessing: HF_677_2HC_Annotation.png: 169
# Preprocessing: HF_677_HC_Annotation.png: 170
# Preprocessing: HF_678_HC_Annotation.png: 171
# Preprocessing: HF_679_HC_Annotation.png: 172
# Preprocessing: HF_680_HC_Annotation.png: 173
# Preprocessing: HF_681_HC_Annotation.png: 174
# Preprocessing: HF_682_HC_Annotation.png: 175
# Preprocessing: HF_683_HC_Annotation.png: 176
# Preprocessing: HF_684_HC_Annotation.png: 177
# Preprocessing: HF_685_HC_Annotation.png: 178
# Preprocessing: HF_686_2HC_Annotation.png: 179
# Preprocessing: HF_686_HC_Annotation.png: 180
# Preprocessing: HF_687_HC_Annotation.png: 181
# Preprocessing: HF_688_HC_Annotation.png: 182
# Preprocessing: HF_689_HC_Annotation.png: 183
# Preprocessing: HF_690_2HC_Annotation.png: 184
# Preprocessing: HF_690_HC_Annotation.png: 185
# Preprocessing: HF_691_HC_Annotation.png: 186
# Preprocessing: HF_692_2HC_Annotation.png: 187
# Preprocessing: HF_692_HC_Annotation.png: 188
# Preprocessing: HF_693_HC_Annotation.png: 189
# Preprocessing: HF_694_HC_Annotation.png: 190
# Preprocessing: HF_695_HC_Annotation.png: 191
# Preprocessing: HF_696_HC_Annotation.png: 192
# Preprocessing: HF_697_HC_Annotation.png: 193
# Preprocessing: HF_698_HC_Annotation.png: 194
# Preprocessing: HF_699_HC_Annotation.png: 195
# Preprocessing: HF_700_HC_Annotation.png: 196
# Preprocessing: HF_701_HC_Annotation.png: 197
# Preprocessing: HF_702_HC_Annotation.png: 198
# Preprocessing: HF_703_HC_Annotation.png: 199
# Preprocessing: HF_704_2HC_Annotation.png: 200
# Preprocessing: HF_704_HC_Annotation.png: 201
# Preprocessing: HF_705_HC_Annotation.png: 202
# Preprocessing: HF_706_HC_Annotation.png: 203
# Preprocessing: HF_707_HC_Annotation.png: 204
# Preprocessing: HF_708_2HC_Annotation.png: 205
# Preprocessing: HF_708_3HC_Annotation.png: 206
# Preprocessing: HF_708_HC_Annotation.png: 207
# Preprocessing: HF_709_2HC_Annotation.png: 208
# Preprocessing: HF_709_HC_Annotation.png: 209
# Preprocessing: HF_710_HC_Annotation.png: 210
# Preprocessing: HF_711_HC_Annotation.png: 211
# Preprocessing: HF_712_2HC_Annotation.png: 212
# Preprocessing: HF_712_HC_Annotation.png: 213
# Preprocessing: HF_713_HC_Annotation.png: 214
# Preprocessing: HF_714_HC_Annotation.png: 215
# Preprocessing: HF_715_HC_Annotation.png: 216
# Preprocessing: HF_716_HC_Annotation.png: 217
# Preprocessing: HF_717_2HC_Annotation.png: 218
# Preprocessing: HF_717_HC_Annotation.png: 219
# Preprocessing: HF_718_2HC_Annotation.png: 220
# Preprocessing: HF_718_HC_Annotation.png: 221
# Preprocessing: HF_719_HC_Annotation.png: 222
