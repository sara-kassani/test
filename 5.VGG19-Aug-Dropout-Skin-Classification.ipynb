# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print(tf.test.gpu_device_name())
# See https://www.tensorflow.org/tutorials/using_gpu#allowing_gpu_memory_growth
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# Out:
# /device:GPU:0

# %%
import os
import pandas as pd

import numpy as np
from glob import glob
import cv2
import skimage
from skimage.transform import resize

from keras import layers
from keras import models
from keras import optimizers
from keras.models import load_model
import keras.callbacks as kcall
from keras.optimizers import Adam
from keras.models import Model
from keras.models import Sequential
from keras.layers import Flatten, Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization
from keras.applications.xception import Xception, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_dir = 'data/train'
validation_dir = 'data/validation'

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
# Out:
# data/train 0
# data/train/MEL 3308
# data/train/DF 4152
# data/train/BKL 3275
# data/train/BCC 4773
# data/train/VASC 3488
# data/train/AKIEC 3856
# data/train/NV 4975

# %%
for root,dirs,files in os.walk(validation_dir):
    print (root, len(files))
# Out:
# data/validation 0
# data/validation/MEL 1664
# data/validation/DF 1632
# data/validation/BKL 1479
# data/validation/BCC 1692
# data/validation/VASC 1484
# data/validation/AKIEC 1552
# data/validation/NV 1730

# %%
from keras.preprocessing.image import ImageDataGenerator

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True)


# target_size = (height, width)
target_size = (225, 300)


train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size = target_size,       
        class_mode = 'categorical',
        shuffle = False)

validation_generator = train_datagen.flow_from_directory(
        validation_dir,
        target_size = target_size,        
        class_mode = 'categorical',
        shuffle = False)
# Out:
# Found 27827 images belonging to 7 classes.
# Found 11233 images belonging to 7 classes.

# %%
import keras.backend as K

def precision(y_true, y_pred):
    # Calculates the precision
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    # Calculates the recall
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def fbeta_score(y_true, y_pred, beta=1):
    # Calculates the F score, the weighted harmonic mean of precision and recall.

    if beta < 0:
        raise ValueError('The lowest choosable beta is zero (only precision).')
        
    # If there are no true positives, fix the F score at 0 like sklearn.
    if K.sum(K.round(K.clip(y_true, 0, 1))) == 0:
        return 0

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    bb = beta ** 2
    fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
    return fbeta_score

def fmeasure(y_true, y_pred):
    # Calculates the f-measure, the harmonic mean of precision and recall.
    return fbeta_score(y_true, y_pred, beta=1)

# %%
## Intilizing variables
output_classes = 7

batch_size = 32 
epochs = 50
droput_rate= 0.5

adam_opt = Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-5)
vgg16_weights= 'pretrained-models/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5'

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import Flatten, Dense, Dropout, BatchNormalization
from keras.regularizers import l2

model = (VGG19(include_top=False, pooling='avg', weights=vgg16_weights))
x = model.output
# x = Flatten()(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
predictions = Dense(7, activation="softmax", kernel_regularizer=l2(0.0001), bias_regularizer=l2(0.0001))(x)
model = Model(input = model.input, output = predictions)


model.compile(loss='categorical_crossentropy',
              optimizer= adam_opt,
              metrics = ["categorical_accuracy", fmeasure, recall, precision])

# %%
history = model.fit_generator(train_generator,
    steps_per_epoch=2048,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps=1024)
# Out:
# Epoch 1/50
# 2048/2048 [==============================] - 962s 470ms/step - loss: 1.5181 - categorical_accuracy: 0.5695 - fmeasure: 0.5586 - recall: 0.5098 - precision: 0.6232 - val_loss: 1.0773 - val_categorical_accuracy: 0.7099 - val_fmeasure: 0.7086 - val_recall: 0.6637 - val_precision: 0.7619
# Epoch 2/50
# 2048/2048 [==============================] - 947s 463ms/step - loss: 0.6967 - categorical_accuracy: 0.8128 - fmeasure: 0.8138 - recall: 0.7877 - precision: 0.8427 - val_loss: 1.3626 - val_categorical_accuracy: 0.6686 - val_fmeasure: 0.6749 - val_recall: 0.6515 - val_precision: 0.7010
# Epoch 3/50
# 2048/2048 [==============================] - 946s 462ms/step - loss: 0.4373 - categorical_accuracy: 0.8955 - fmeasure: 0.8963 - recall: 0.8841 - precision: 0.9094 - val_loss: 0.6727 - val_categorical_accuracy: 0.8384 - val_fmeasure: 0.8388 - val_recall: 0.8259 - val_precision: 0.8525
# Epoch 4/50
# 2048/2048 [==============================] - 946s 462ms/step - loss: 0.2916 - categorical_accuracy: 0.9419 - fmeasure: 0.9416 - recall: 0.9362 - precision: 0.9474 - val_loss: 1.0286 - val_categorical_accuracy: 0.8069 - val_fmeasure: 0.8071 - val_recall: 0.8006 - val_precision: 0.8140
# Epoch 5/50
# Epoch 36/50
# 2048/2048 [==============================] - 947s 462ms/step - loss: 0.0673 - categorical_accuracy: 0.9983 - fmeasure: 0.9983 - recall: 0.9983 - precision: 0.9984 - val_loss: 0.8330 - val_categorical_accuracy: 0.8887 - val_fmeasure: 0.8894 - val_recall: 0.8880 - val_precision: 0.8907
# Epoch 37/50
# 2048/2048 [==============================] - 947s 462ms/step - loss: 0.0654 - categorical_accuracy: 0.9989 - fmeasure: 0.9989 - recall: 0.9988 - precision: 0.9989 - val_loss: 0.9784 - val_categorical_accuracy: 0.8811 - val_fmeasure: 0.8813 - val_recall: 0.8800 - val_precision: 0.8827
# Epoch 38/50
# 2048/2048 [==============================] - 947s 462ms/step - loss: 0.0654 - categorical_accuracy: 0.9985 - fmeasure: 0.9985 - recall: 0.9984 - precision: 0.9985 - val_loss: 0.9802 - val_categorical_accuracy: 0.8778 - val_fmeasure: 0.8783 - val_recall: 0.8764 - val_precision: 0.8803
# Epoch 39/50
# 2048/2048 [==============================] - 947s 462ms/step - loss: 0.0641 - categorical_accuracy: 0.9986 - fmeasure: 0.9986 - recall: 0.9986 - precision: 0.9986 - val_loss: 1.0339 - val_categorical_accuracy: 0.8720 - val_fmeasure: 0.8725 - val_recall: 0.8712 - val_precision: 0.8739
# Epoch 40/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0626 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9988 - precision: 0.9988 - val_loss: 0.8662 - val_categorical_accuracy: 0.8903 - val_fmeasure: 0.8907 - val_recall: 0.8893 - val_precision: 0.8920
# Epoch 41/50
# 2048/2048 [==============================] - 950s 464ms/step - loss: 0.0630 - categorical_accuracy: 0.9987 - fmeasure: 0.9987 - recall: 0.9987 - precision: 0.9987 - val_loss: 0.9696 - val_categorical_accuracy: 0.8798 - val_fmeasure: 0.8803 - val_recall: 0.8794 - val_precision: 0.8812
# Epoch 42/50
# 2048/2048 [==============================] - 949s 463ms/step - loss: 0.0612 - categorical_accuracy: 0.9991 - fmeasure: 0.9991 - recall: 0.9991 - precision: 0.9991 - val_loss: 1.2096 - val_categorical_accuracy: 0.8523 - val_fmeasure: 0.8530 - val_recall: 0.8515 - val_precision: 0.8546
# Epoch 43/50
# 2048/2048 [==============================] - 949s 463ms/step - loss: 0.0612 - categorical_accuracy: 0.9987 - fmeasure: 0.9987 - recall: 0.9987 - precision: 0.9988 - val_loss: 0.9791 - val_categorical_accuracy: 0.8828 - val_fmeasure: 0.8835 - val_recall: 0.8819 - val_precision: 0.8852
# Epoch 44/50
# 2048/2048 [==============================] - 950s 464ms/step - loss: 0.0586 - categorical_accuracy: 0.9994 - fmeasure: 0.9994 - recall: 0.9994 - precision: 0.9994 - val_loss: 1.3981 - val_categorical_accuracy: 0.8138 - val_fmeasure: 0.8137 - val_recall: 0.8123 - val_precision: 0.8151
# Epoch 45/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0598 - categorical_accuracy: 0.9987 - fmeasure: 0.9987 - recall: 0.9987 - precision: 0.9987 - val_loss: 1.4616 - val_categorical_accuracy: 0.8240 - val_fmeasure: 0.8242 - val_recall: 0.8229 - val_precision: 0.8255
# Epoch 46/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0581 - categorical_accuracy: 0.9991 - fmeasure: 0.9992 - recall: 0.9991 - precision: 0.9992 - val_loss: 0.7586 - val_categorical_accuracy: 0.8810 - val_fmeasure: 0.8819 - val_recall: 0.8790 - val_precision: 0.8850
# Epoch 47/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0561 - categorical_accuracy: 0.9995 - fmeasure: 0.9995 - recall: 0.9995 - precision: 0.9995 - val_loss: 0.9241 - val_categorical_accuracy: 0.8857 - val_fmeasure: 0.8863 - val_recall: 0.8845 - val_precision: 0.8882
# Epoch 48/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0582 - categorical_accuracy: 0.9986 - fmeasure: 0.9986 - recall: 0.9986 - precision: 0.9986 - val_loss: 0.7688 - val_categorical_accuracy: 0.8901 - val_fmeasure: 0.8908 - val_recall: 0.8896 - val_precision: 0.8920
# Epoch 49/50
# 2048/2048 [==============================] - 948s 463ms/step - loss: 0.0559 - categorical_accuracy: 0.9993 - fmeasure: 0.9993 - recall: 0.9993 - precision: 0.9993 - val_loss: 1.2462 - val_categorical_accuracy: 0.8340 - val_fmeasure: 0.8348 - val_recall: 0.8327 - val_precision: 0.8369
# Epoch 50/50
# 2048/2048 [==============================] - 949s 463ms/step - loss: 0.0561 - categorical_accuracy: 0.9988 - fmeasure: 0.9988 - recall: 0.9988 - precision: 0.9988 - val_loss: 0.7996 - val_categorical_accuracy: 0.8868 - val_fmeasure: 0.8871 - val_recall: 0.8854 - val_precision: 0.8889

# %%
score = model.evaluate_generator(validation_generator, steps=50)

print ('Test Score: ', score[0])
print ('Test Accuracy: ',score[1])
print ('fmeasure: ', score[2])
print ('Recall: ', score[3])
print ('Precision: ', score[4])
# Out:
# Test Score:  0.8713675609976054
# Test Accuracy:  0.883125
# fmeasure:  0.882995971441269
# Recall:  0.881875
# Precision:  0.8841532242298126

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["categorical_accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_categorical_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %%
filename = validation_generator.filenames
truth = validation_generator.classes
label = validation_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

# %%
predicts = model.predict_generator(validation_generator, steps=validation_generator.samples/validation_generator.batch_size, verbose=1)
predict_class = np.argmax(predicts, axis=1)
errors = np.where(predict_class != truth)[0]
print("No of errors = {}/{}".format(len(errors),validation_generator.samples))
# Out:
# 352/351 [==============================] - 3569s 10s/step
# No of errors = 1272/11233

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))    

plt.figure(figsize=(10,10))


plot_confusion_matrix(cm, classes=labels,
                      title='Confusion Matrix')
# Out:
# Confusion Matrix
# [[1432   12   70    0   26   12    0]
#  [  69 1563   38    1   12    9    0]
#  [  40    4 1363    1   44   27    0]
#  [  62   26   48 1441   20   35    0]
#  [  14    4   52    1 1536   55    2]
#  [  20    7   59    1  120 1522    1]
#  [   0    8   32    0    0  340 1104]]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truth,predict_class)

labels = []
for k,v in indexlabel.items():
    labels.append(v)
    
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, classes=labels,
                      title='Confusion matrix')
# Out:
# Confusion matrix
# [[1432   12   70    0   26   12    0]
#  [  69 1563   38    1   12    9    0]
#  [  40    4 1363    1   44   27    0]
#  [  62   26   48 1441   20   35    0]
#  [  14    4   52    1 1536   55    2]
#  [  20    7   59    1  120 1522    1]
#  [   0    8   32    0    0  340 1104]]

# %%
model.save('models/5.VGG19-Adam-Dropout-Model.h5')
model.save_weights('models/VGG19-Adam-Dropout-Weights.h5')

# %%
from keras.models import load_model
model = load_model("models/5.VGG19-Adam-Dropout-Model.h5", custom_objects={'fmeasure': fmeasure,  'recall': recall, 'precision': precision })
model.load_weights("models/VGG19-Adam-Dropout-Weights.h5")

# %% [markdown]
# ____

# %%
import numpy as np
