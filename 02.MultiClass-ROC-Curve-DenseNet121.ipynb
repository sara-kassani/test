# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import keras
import tensorflow as tf
import keras.backend as K

print("Keras Version", keras.__version__)
print("tensorflow Version", tf.__version__)
print("dim_ordering:", K.image_dim_ordering())
# Out:
# Using TensorFlow backend.
# Keras Version 2.2.4
# tensorflow Version 1.4.0
# dim_ordering: tf

# %%
import os
import math
import numpy as np

from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.layers import Dropout, Flatten, Dense, AveragePooling2D
from keras import applications
from keras.utils.np_utils import to_categorical
from sklearn.metrics import accuracy_score,roc_curve, confusion_matrix, roc_auc_score, auc, f1_score
from keras.models import load_model

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_dir = 'data/512/train/'
test_dir = "data/512/test"

extracted_features_dir = "extracted_features/"
model_name = "DenseNet121_512"

# %%
for root,dirs,files in os.walk(train_dir):
    print (root, len(files))
print("***"*15)
for root,dirs,files in os.walk(test_dir):
    print (root, len(files))
# Out:
# data/512/train/ 0
# data/512/train/Invasive 1155
# data/512/train/Benign 1155
# data/512/train/InSitu 1155
# data/512/train/Normal 1155
# *********************************************
# data/512/test 0
# data/512/test/Invasive 25
# data/512/test/Benign 25
# data/512/test/InSitu 25
# data/512/test/Normal 25

# %%
output_classes = 4
batch_size = 32
img_height, img_width = 512, 384
input_shape = (img_height, img_width, 3)
epochs = 1000

top_model_path = os.path.join(extracted_features_dir, 'bottleneck_fc_'+model_name+'_model.h5')
top_model_weights_path = os.path.join(extracted_features_dir, 'bottleneck_fc_'+model_name+'_weights.h5')

# %%
random_seed = np.random.seed(1142)

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split= 0.25,
    zoom_range=0.2,
    shear_range=0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'training',
    class_mode='categorical')

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    subset = 'validation',
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    seed = random_seed,
    shuffle = False,
    class_mode='categorical')
# Out:
# Found 3468 images belonging to 4 classes.
# Found 1152 images belonging to 4 classes.
# Found 100 images belonging to 4 classes.

# %%
nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
predict_size_train = int(math.ceil(nb_train_samples / batch_size))
predict_size_validation = int(math.ceil(nb_validation_samples / batch_size))
nb_test_samples = len(test_generator.filenames)
predict_size_test = int(math.ceil(nb_test_samples / batch_size))

num_classes = len(train_generator.class_indices)

print("nb_train_samples:", nb_train_samples)
print("nb_validation_samples:", nb_validation_samples)
print("nb_test_samples:", nb_test_samples)

print("\npredict_size_train:", predict_size_train)
print("predict_size_validation:", predict_size_validation)
print("predict_size_test:", predict_size_test)

print("\n num_classes:", num_classes)
# Out:
# nb_train_samples: 3468
# nb_validation_samples: 1152
# nb_test_samples: 100
#
# predict_size_train: 109
# predict_size_validation: 36
# predict_size_test: 4
#
#  num_classes: 4

# %%
bottleneck_final_model = applications.DenseNet121(include_top=False, weights='imagenet', pooling='avg')

bottleneck_features_train = bottleneck_final_model.predict_generator(train_generator, predict_size_train)
np.save(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy', bottleneck_features_train)

bottleneck_features_validation = bottleneck_final_model.predict_generator(validation_generator, predict_size_validation)
np.save(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy', bottleneck_features_validation)

bottleneck_features_test = bottleneck_final_model.predict_generator(test_generator, predict_size_test)
np.save(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy', bottleneck_features_test)

# %%
train_data = np.load(extracted_features_dir+'bottleneck_features_train_'+model_name+'.npy')
validation_data = np.load(extracted_features_dir+'bottleneck_features_validation_'+model_name+'.npy')
test_data = np.load(extracted_features_dir+'bottleneck_features_test_'+model_name+'.npy')

train_labels = train_generator.classes
train_labels = to_categorical(train_labels, num_classes=num_classes)

validation_labels = validation_generator.classes
validation_labels = to_categorical(validation_labels, num_classes=num_classes)

test_labels = test_generator.classes
test_labels = to_categorical(test_labels, num_classes=num_classes)

# %%
dropout_rate = 0.5

model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(256, activation='relu'))
model.add(Dropout(dropout_rate))
model.add(Dense(num_classes, activation=tf.nn.softmax))

adam_opt2=Adam(lr = 0.001, beta_1=0.6, beta_2=0.8, amsgrad=True)

model.compile(optimizer=adam_opt2, loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_data, train_labels,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(validation_data, validation_labels),
                    verbose= 2)

with open(extracted_features_dir+'history_'+model_name+'.txt','w') as f:
    f.write(str(history.history))

model.save_weights(top_model_weights_path)
model.save(top_model_path)
# Out:
# Train on 3468 samples, validate on 1152 samples
# Epoch 1/1000
#  - 2s - loss: 0.9996 - acc: 0.5750 - val_loss: 0.6740 - val_acc: 0.7613
# Epoch 2/1000
#  - 1s - loss: 0.6752 - acc: 0.7333 - val_loss: 0.5270 - val_acc: 0.8290
# Epoch 3/1000
#  - 1s - loss: 0.5308 - acc: 0.8005 - val_loss: 0.4315 - val_acc: 0.8646
# Epoch 4/1000
#  - 1s - loss: 0.4520 - acc: 0.8423 - val_loss: 0.3872 - val_acc: 0.8767
# Epoch 5/1000
#  - 1s - loss: 0.3864 - acc: 0.8691 - val_loss: 0.3181 - val_acc: 0.9080
# Epoch 6/1000
#  - 1s - loss: 0.3245 - acc: 0.8919 - val_loss: 0.2754 - val_acc: 0.9201
# Epoch 7/1000
#  - 1s - loss: 0.2976 - acc: 0.9034 - val_loss: 0.2265 - val_acc: 0.9470
# Epoch 8/1000
#  - 1s - loss: 0.2560 - acc: 0.9259 - val_loss: 0.2324 - val_acc: 0.9297
# Epoch 9/1000
#  - 1s - loss: 0.2299 - acc: 0.9311 - val_loss: 0.1801 - val_acc: 0.9601
# Epoch 10/1000
#  - 1s - loss: 0.2103 - acc: 0.9403 - val_loss: 0.1656 - val_acc: 0.9627
# Epoch 11/1000
#  - 1s - loss: 0.1934 - acc: 0.9446 - val_loss: 0.1636 - val_acc: 0.9583
# Epoch 12/1000
#  - 1s - loss: 0.1745 - acc: 0.9504 - val_loss: 0.1469 - val_acc: 0.9670
# Epoch 13/1000
#  - 1s - loss: 0.1584 - acc: 0.9553 - val_loss: 0.1288 - val_acc: 0.9722
# Epoch 14/1000
#  - 1s - loss: 0.1431 - acc: 0.9654 - val_loss: 0.1208 - val_acc: 0.9731
# Epoch 15/1000
#  - 1s - loss: 0.1363 - acc: 0.9666 - val_loss: 0.1201 - val_acc: 0.9722
# Epoch 16/1000
#  - 1s - loss: 0.1307 - acc: 0.9683 - val_loss: 0.1076 - val_acc: 0.9809
# Epoch 17/1000
#  - 1s - loss: 0.1208 - acc: 0.9680 - val_loss: 0.0993 - val_acc: 0.9783
# Epoch 18/1000
#  - 1s - loss: 0.1045 - acc: 0.9781 - val_loss: 0.0902 - val_acc: 0.9835
# Epoch 19/1000
#  - 1s - loss: 0.1029 - acc: 0.9758 - val_loss: 0.0883 - val_acc: 0.9878
# Epoch 20/1000
#  - 1s - loss: 0.1024 - acc: 0.9775 - val_loss: 0.0903 - val_acc: 0.9783
# Epoch 21/1000
#  - 1s - loss: 0.0937 - acc: 0.9790 - val_loss: 0.0777 - val_acc: 0.9887
# Epoch 22/1000
#  - 1s - loss: 0.0879 - acc: 0.9804 - val_loss: 0.0757 - val_acc: 0.9878
# Epoch 23/1000
#  - 1s - loss: 0.0811 - acc: 0.9839 - val_loss: 0.0747 - val_acc: 0.9852
# Epoch 24/1000
#  - 1s - loss: 0.0798 - acc: 0.9807 - val_loss: 0.0804 - val_acc: 0.9809
# Epoch 25/1000
#  - 1s - loss: 0.0819 - acc: 0.9798 - val_loss: 0.0654 - val_acc: 0.9896
# Epoch 26/1000
#  - 1s - loss: 0.0744 - acc: 0.9853 - val_loss: 0.0732 - val_acc: 0.9861
# Epoch 27/1000
#  - 1s - loss: 0.0670 - acc: 0.9867 - val_loss: 0.0591 - val_acc: 0.9931
# Epoch 28/1000
#  - 1s - loss: 0.0657 - acc: 0.9867 - val_loss: 0.0631 - val_acc: 0.9887
# Epoch 29/1000
#  - 1s - loss: 0.0646 - acc: 0.9882 - val_loss: 0.0575 - val_acc: 0.9905
# Epoch 30/1000
#  - 1s - loss: 0.0597 - acc: 0.9873 - val_loss: 0.0632 - val_acc: 0.9870
# Epoch 31/1000
#  - 1s - loss: 0.0555 - acc: 0.9919 - val_loss: 0.0534 - val_acc: 0.9913
# Epoch 32/1000
#  - 1s - loss: 0.0577 - acc: 0.9882 - val_loss: 0.0632 - val_acc: 0.9878
# Epoch 33/1000
#  - 1s - loss: 0.0566 - acc: 0.9885 - val_loss: 0.0540 - val_acc: 0.9896
# Epoch 34/1000
#  - 1s - loss: 0.0466 - acc: 0.9951 - val_loss: 0.0472 - val_acc: 0.9922
# Epoch 35/1000
#  - 1s - loss: 0.0489 - acc: 0.9928 - val_loss: 0.0466 - val_acc: 0.9913
# Epoch 36/1000
#  - 1s - loss: 0.0468 - acc: 0.9928 - val_loss: 0.0445 - val_acc: 0.9931
# Epoch 37/1000
#  - 1s - loss: 0.0448 - acc: 0.9945 - val_loss: 0.0432 - val_acc: 0.9939
# Epoch 38/1000
#  - 1s - loss: 0.0432 - acc: 0.9931 - val_loss: 0.0442 - val_acc: 0.9939
# Epoch 39/1000
#  - 1s - loss: 0.0419 - acc: 0.9939 - val_loss: 0.0450 - val_acc: 0.9931
# Epoch 40/1000
#  - 1s - loss: 0.0407 - acc: 0.9928 - val_loss: 0.0479 - val_acc: 0.9931
# Epoch 41/1000
#  - 1s - loss: 0.0406 - acc: 0.9937 - val_loss: 0.0474 - val_acc: 0.9905
# Epoch 42/1000
#  - 1s - loss: 0.0371 - acc: 0.9954 - val_loss: 0.0444 - val_acc: 0.9913
# Epoch 43/1000
#  - 1s - loss: 0.0356 - acc: 0.9945 - val_loss: 0.0472 - val_acc: 0.9913
# Epoch 44/1000
#  - 1s - loss: 0.0369 - acc: 0.9934 - val_loss: 0.0393 - val_acc: 0.9939
# Epoch 45/1000
#  - 1s - loss: 0.0309 - acc: 0.9963 - val_loss: 0.0454 - val_acc: 0.9922
# Epoch 46/1000
#  - 1s - loss: 0.0328 - acc: 0.9957 - val_loss: 0.0419 - val_acc: 0.9922
# Epoch 47/1000
#  - 1s - loss: 0.0350 - acc: 0.9939 - val_loss: 0.0380 - val_acc: 0.9931
# Epoch 48/1000
#  - 1s - loss: 0.0293 - acc: 0.9971 - val_loss: 0.0389 - val_acc: 0.9939
# Epoch 49/1000
#  - 1s - loss: 0.0283 - acc: 0.9960 - val_loss: 0.0398 - val_acc: 0.9931
# Epoch 50/1000
#  - 1s - loss: 0.0279 - acc: 0.9980 - val_loss: 0.0375 - val_acc: 0.9939
# Epoch 51/1000
#  - 1s - loss: 0.0293 - acc: 0.9980 - val_loss: 0.0377 - val_acc: 0.9931
# Epoch 52/1000
#  - 1s - loss: 0.0271 - acc: 0.9963 - val_loss: 0.0362 - val_acc: 0.9931
# Epoch 53/1000
#  - 1s - loss: 0.0304 - acc: 0.9957 - val_loss: 0.0388 - val_acc: 0.9922
# Epoch 54/1000
#  - 1s - loss: 0.0264 - acc: 0.9968 - val_loss: 0.0369 - val_acc: 0.9922
# Epoch 55/1000
#  - 1s - loss: 0.0278 - acc: 0.9965 - val_loss: 0.0357 - val_acc: 0.9931
# Epoch 56/1000
#  - 1s - loss: 0.0256 - acc: 0.9968 - val_loss: 0.0372 - val_acc: 0.9939
# Epoch 57/1000
#  - 1s - loss: 0.0223 - acc: 0.9983 - val_loss: 0.0327 - val_acc: 0.9939
# Epoch 58/1000
#  - 1s - loss: 0.0226 - acc: 0.9977 - val_loss: 0.0321 - val_acc: 0.9922
# Epoch 59/1000
#  - 1s - loss: 0.0256 - acc: 0.9974 - val_loss: 0.0311 - val_acc: 0.9931
# Epoch 60/1000
#  - 1s - loss: 0.0265 - acc: 0.9968 - val_loss: 0.0327 - val_acc: 0.9948
# Epoch 61/1000
#  - 1s - loss: 0.0241 - acc: 0.9971 - val_loss: 0.0321 - val_acc: 0.9931
# Epoch 62/1000
#  - 1s - loss: 0.0225 - acc: 0.9974 - val_loss: 0.0319 - val_acc: 0.9948
# Epoch 63/1000
#  - 1s - loss: 0.0213 - acc: 0.9977 - val_loss: 0.0322 - val_acc: 0.9931
# Epoch 64/1000
#  - 1s - loss: 0.0215 - acc: 0.9983 - val_loss: 0.0314 - val_acc: 0.9931
# Epoch 65/1000
#  - 1s - loss: 0.0221 - acc: 0.9980 - val_loss: 0.0305 - val_acc: 0.9939
# Epoch 66/1000
#  - 1s - loss: 0.0196 - acc: 0.9980 - val_loss: 0.0298 - val_acc: 0.9939
# Epoch 67/1000
#  - 1s - loss: 0.0214 - acc: 0.9974 - val_loss: 0.0315 - val_acc: 0.9939
# Epoch 68/1000
#  - 1s - loss: 0.0189 - acc: 0.9988 - val_loss: 0.0299 - val_acc: 0.9939
# Epoch 69/1000
#  - 1s - loss: 0.0185 - acc: 0.9986 - val_loss: 0.0286 - val_acc: 0.9948
# Epoch 70/1000
#  - 1s - loss: 0.0191 - acc: 0.9991 - val_loss: 0.0296 - val_acc: 0.9939
# Epoch 71/1000
#  - 1s - loss: 0.0196 - acc: 0.9980 - val_loss: 0.0313 - val_acc: 0.9931
# Epoch 72/1000
#  - 1s - loss: 0.0178 - acc: 0.9988 - val_loss: 0.0301 - val_acc: 0.9931
# Epoch 73/1000
#  - 1s - loss: 0.0162 - acc: 0.9988 - val_loss: 0.0292 - val_acc: 0.9939
# Epoch 74/1000
#  - 1s - loss: 0.0168 - acc: 0.9988 - val_loss: 0.0305 - val_acc: 0.9931
# Epoch 75/1000
#  - 1s - loss: 0.0171 - acc: 0.9986 - val_loss: 0.0323 - val_acc: 0.9913
# Epoch 76/1000
#  - 1s - loss: 0.0165 - acc: 0.9983 - val_loss: 0.0306 - val_acc: 0.9939
# Epoch 77/1000
#  - 1s - loss: 0.0145 - acc: 0.9994 - val_loss: 0.0346 - val_acc: 0.9931
# Epoch 78/1000
#  - 1s - loss: 0.0168 - acc: 0.9991 - val_loss: 0.0292 - val_acc: 0.9948
# Epoch 79/1000
#  - 1s - loss: 0.0166 - acc: 0.9983 - val_loss: 0.0299 - val_acc: 0.9939
# Epoch 80/1000
#  - 1s - loss: 0.0157 - acc: 0.9986 - val_loss: 0.0302 - val_acc: 0.9939
# Epoch 81/1000
#  - 1s - loss: 0.0154 - acc: 0.9991 - val_loss: 0.0257 - val_acc: 0.9939
# Epoch 82/1000
#  - 1s - loss: 0.0168 - acc: 0.9986 - val_loss: 0.0262 - val_acc: 0.9939
# Epoch 83/1000
#  - 1s - loss: 0.0145 - acc: 0.9988 - val_loss: 0.0275 - val_acc: 0.9931
# Epoch 84/1000
#  - 1s - loss: 0.0147 - acc: 0.9986 - val_loss: 0.0282 - val_acc: 0.9939
# Epoch 85/1000
#  - 1s - loss: 0.0154 - acc: 0.9977 - val_loss: 0.0271 - val_acc: 0.9948
# Epoch 86/1000
#  - 1s - loss: 0.0139 - acc: 0.9994 - val_loss: 0.0270 - val_acc: 0.9931
# Epoch 87/1000
#  - 1s - loss: 0.0136 - acc: 0.9991 - val_loss: 0.0300 - val_acc: 0.9931
# Epoch 88/1000
#  - 1s - loss: 0.0136 - acc: 0.9991 - val_loss: 0.0286 - val_acc: 0.9939
# Epoch 89/1000
#  - 1s - loss: 0.0146 - acc: 0.9983 - val_loss: 0.0281 - val_acc: 0.9939
# Epoch 90/1000
#  - 1s - loss: 0.0138 - acc: 0.9988 - val_loss: 0.0290 - val_acc: 0.9939
# Epoch 91/1000
#  - 1s - loss: 0.0122 - acc: 0.9994 - val_loss: 0.0251 - val_acc: 0.9939
# Epoch 92/1000
#  - 1s - loss: 0.0133 - acc: 0.9994 - val_loss: 0.0259 - val_acc: 0.9948
# Epoch 93/1000
#  - 1s - loss: 0.0122 - acc: 0.9994 - val_loss: 0.0257 - val_acc: 0.9931
# Epoch 94/1000
#  - 1s - loss: 0.0130 - acc: 0.9991 - val_loss: 0.0257 - val_acc: 0.9939
# Epoch 95/1000
#  - 1s - loss: 0.0128 - acc: 0.9994 - val_loss: 0.0266 - val_acc: 0.9931
# Epoch 96/1000
#  - 1s - loss: 0.0122 - acc: 1.0000 - val_loss: 0.0255 - val_acc: 0.9948
# Epoch 97/1000
#  - 1s - loss: 0.0143 - acc: 0.9980 - val_loss: 0.0254 - val_acc: 0.9957
# Epoch 98/1000
#  - 1s - loss: 0.0128 - acc: 0.9988 - val_loss: 0.0266 - val_acc: 0.9939
# Epoch 99/1000
#  - 1s - loss: 0.0110 - acc: 0.9997 - val_loss: 0.0263 - val_acc: 0.9931
# Epoch 100/1000
#  - 1s - loss: 0.0115 - acc: 0.9994 - val_loss: 0.0257 - val_acc: 0.9948
# Epoch 101/1000
#  - 1s - loss: 0.0127 - acc: 0.9988 - val_loss: 0.0284 - val_acc: 0.9939
# Epoch 102/1000
#  - 1s - loss: 0.0115 - acc: 0.9994 - val_loss: 0.0267 - val_acc: 0.9939
# Epoch 103/1000
#  - 1s - loss: 0.0109 - acc: 0.9997 - val_loss: 0.0243 - val_acc: 0.9948
# Epoch 104/1000
#  - 1s - loss: 0.0103 - acc: 0.9991 - val_loss: 0.0268 - val_acc: 0.9948
# Epoch 105/1000
#  - 1s - loss: 0.0102 - acc: 0.9997 - val_loss: 0.0246 - val_acc: 0.9948
# Epoch 106/1000
#  - 1s - loss: 0.0109 - acc: 0.9986 - val_loss: 0.0264 - val_acc: 0.9939
# Epoch 107/1000
#  - 1s - loss: 0.0116 - acc: 0.9988 - val_loss: 0.0248 - val_acc: 0.9939
# Epoch 108/1000
#  - 1s - loss: 0.0105 - acc: 0.9997 - val_loss: 0.0247 - val_acc: 0.9939
# Epoch 109/1000
#  - 1s - loss: 0.0092 - acc: 0.9994 - val_loss: 0.0253 - val_acc: 0.9939
# Epoch 110/1000
#  - 1s - loss: 0.0097 - acc: 0.9994 - val_loss: 0.0253 - val_acc: 0.9939
# Epoch 111/1000
#  - 1s - loss: 0.0094 - acc: 0.9994 - val_loss: 0.0274 - val_acc: 0.9939
# Epoch 112/1000
#  - 1s - loss: 0.0094 - acc: 0.9994 - val_loss: 0.0232 - val_acc: 0.9939
# Epoch 113/1000
#  - 1s - loss: 0.0091 - acc: 0.9994 - val_loss: 0.0241 - val_acc: 0.9948
# Epoch 114/1000
#  - 1s - loss: 0.0094 - acc: 1.0000 - val_loss: 0.0232 - val_acc: 0.9931
# Epoch 115/1000
#  - 1s - loss: 0.0089 - acc: 0.9997 - val_loss: 0.0257 - val_acc: 0.9939
# Epoch 116/1000
#  - 1s - loss: 0.0099 - acc: 0.9991 - val_loss: 0.0257 - val_acc: 0.9931
# Epoch 117/1000
#  - 1s - loss: 0.0093 - acc: 1.0000 - val_loss: 0.0237 - val_acc: 0.9948
# Epoch 118/1000
#  - 1s - loss: 0.0102 - acc: 0.9988 - val_loss: 0.0275 - val_acc: 0.9913
# Epoch 119/1000
#  - 1s - loss: 0.0083 - acc: 0.9994 - val_loss: 0.0236 - val_acc: 0.9939
# Epoch 120/1000
#  - 1s - loss: 0.0089 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 121/1000
#  - 1s - loss: 0.0089 - acc: 0.9997 - val_loss: 0.0246 - val_acc: 0.9939
# Epoch 122/1000
#  - 1s - loss: 0.0083 - acc: 0.9997 - val_loss: 0.0246 - val_acc: 0.9939
# Epoch 123/1000
#  - 1s - loss: 0.0100 - acc: 0.9988 - val_loss: 0.0244 - val_acc: 0.9939
# Epoch 124/1000
#  - 1s - loss: 0.0083 - acc: 1.0000 - val_loss: 0.0248 - val_acc: 0.9939
# Epoch 125/1000
#  - 1s - loss: 0.0085 - acc: 0.9997 - val_loss: 0.0232 - val_acc: 0.9939
# Epoch 126/1000
#  - 1s - loss: 0.0081 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 0.9948
# Epoch 127/1000
#  - 1s - loss: 0.0088 - acc: 0.9991 - val_loss: 0.0226 - val_acc: 0.9948
# Epoch 128/1000
#  - 1s - loss: 0.0080 - acc: 0.9997 - val_loss: 0.0274 - val_acc: 0.9939
# Epoch 129/1000
#  - 1s - loss: 0.0084 - acc: 0.9994 - val_loss: 0.0231 - val_acc: 0.9939
# Epoch 130/1000
#  - 1s - loss: 0.0075 - acc: 0.9997 - val_loss: 0.0240 - val_acc: 0.9939
# Epoch 131/1000
#  - 1s - loss: 0.0070 - acc: 0.9997 - val_loss: 0.0215 - val_acc: 0.9948
# Epoch 132/1000
#  - 1s - loss: 0.0078 - acc: 0.9997 - val_loss: 0.0228 - val_acc: 0.9939
# Epoch 133/1000
#  - 1s - loss: 0.0072 - acc: 0.9997 - val_loss: 0.0231 - val_acc: 0.9939
# Epoch 134/1000
#  - 1s - loss: 0.0073 - acc: 0.9997 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 135/1000
#  - 1s - loss: 0.0063 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9948
# Epoch 136/1000
#  - 1s - loss: 0.0072 - acc: 0.9997 - val_loss: 0.0237 - val_acc: 0.9939
# Epoch 137/1000
#  - 1s - loss: 0.0081 - acc: 0.9994 - val_loss: 0.0253 - val_acc: 0.9939
# Epoch 138/1000
#  - 1s - loss: 0.0074 - acc: 0.9997 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 139/1000
#  - 1s - loss: 0.0079 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 140/1000
#  - 1s - loss: 0.0082 - acc: 0.9991 - val_loss: 0.0230 - val_acc: 0.9948
# Epoch 141/1000
#  - 1s - loss: 0.0080 - acc: 0.9991 - val_loss: 0.0232 - val_acc: 0.9948
# Epoch 142/1000
#  - 1s - loss: 0.0077 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 143/1000
#  - 1s - loss: 0.0084 - acc: 0.9994 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 144/1000
#  - 1s - loss: 0.0081 - acc: 0.9988 - val_loss: 0.0233 - val_acc: 0.9939
# Epoch 145/1000
#  - 1s - loss: 0.0081 - acc: 0.9997 - val_loss: 0.0225 - val_acc: 0.9948
# Epoch 146/1000
#  - 1s - loss: 0.0070 - acc: 0.9994 - val_loss: 0.0233 - val_acc: 0.9939
# Epoch 147/1000
#  - 1s - loss: 0.0078 - acc: 0.9994 - val_loss: 0.0212 - val_acc: 0.9957
# Epoch 148/1000
#  - 1s - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0228 - val_acc: 0.9939
# Epoch 149/1000
#  - 1s - loss: 0.0069 - acc: 0.9994 - val_loss: 0.0254 - val_acc: 0.9939
# Epoch 150/1000
#  - 1s - loss: 0.0072 - acc: 0.9997 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 151/1000
#  - 1s - loss: 0.0070 - acc: 0.9997 - val_loss: 0.0233 - val_acc: 0.9939
# Epoch 152/1000
#  - 1s - loss: 0.0062 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9948
# Epoch 153/1000
#  - 1s - loss: 0.0070 - acc: 1.0000 - val_loss: 0.0250 - val_acc: 0.9939
# Epoch 154/1000
#  - 1s - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0251 - val_acc: 0.9939
# Epoch 155/1000
#  - 1s - loss: 0.0065 - acc: 0.9997 - val_loss: 0.0236 - val_acc: 0.9939
# Epoch 156/1000
#  - 1s - loss: 0.0070 - acc: 0.9997 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 157/1000
#  - 1s - loss: 0.0073 - acc: 0.9988 - val_loss: 0.0214 - val_acc: 0.9948
# Epoch 158/1000
#  - 1s - loss: 0.0070 - acc: 0.9991 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 159/1000
#  - 1s - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 160/1000
#  - 1s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 161/1000
#  - 1s - loss: 0.0067 - acc: 0.9994 - val_loss: 0.0244 - val_acc: 0.9939
# Epoch 162/1000
#  - 1s - loss: 0.0070 - acc: 0.9991 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 163/1000
#  - 1s - loss: 0.0060 - acc: 0.9997 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 164/1000
#  - 1s - loss: 0.0061 - acc: 0.9997 - val_loss: 0.0233 - val_acc: 0.9939
# Epoch 165/1000
#  - 1s - loss: 0.0068 - acc: 1.0000 - val_loss: 0.0247 - val_acc: 0.9939
# Epoch 166/1000
#  - 1s - loss: 0.0060 - acc: 0.9997 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 167/1000
#  - 1s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 168/1000
#  - 1s - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 0.9939
# Epoch 169/1000
#  - 1s - loss: 0.0057 - acc: 1.0000 - val_loss: 0.0237 - val_acc: 0.9939
# Epoch 170/1000
#  - 1s - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 171/1000
#  - 1s - loss: 0.0062 - acc: 0.9991 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 172/1000
#  - 1s - loss: 0.0066 - acc: 0.9991 - val_loss: 0.0224 - val_acc: 0.9939
# Epoch 173/1000
#  - 1s - loss: 0.0054 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 174/1000
#  - 1s - loss: 0.0056 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 175/1000
#  - 1s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9939
# Epoch 176/1000
#  - 1s - loss: 0.0052 - acc: 0.9997 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 177/1000
#  - 1s - loss: 0.0065 - acc: 0.9994 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 178/1000
#  - 1s - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 179/1000
#  - 1s - loss: 0.0050 - acc: 0.9994 - val_loss: 0.0248 - val_acc: 0.9939
# Epoch 180/1000
#  - 1s - loss: 0.0053 - acc: 0.9997 - val_loss: 0.0218 - val_acc: 0.9948
# Epoch 181/1000
#  - 1s - loss: 0.0057 - acc: 0.9994 - val_loss: 0.0208 - val_acc: 0.9948
# Epoch 182/1000
#  - 1s - loss: 0.0059 - acc: 0.9994 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 183/1000
#  - 1s - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 184/1000
#  - 1s - loss: 0.0052 - acc: 0.9991 - val_loss: 0.0257 - val_acc: 0.9939
# Epoch 185/1000
#  - 1s - loss: 0.0054 - acc: 0.9997 - val_loss: 0.0232 - val_acc: 0.9939
# Epoch 186/1000
#  - 1s - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 187/1000
#  - 1s - loss: 0.0055 - acc: 0.9994 - val_loss: 0.0245 - val_acc: 0.9939
# Epoch 188/1000
#  - 1s - loss: 0.0055 - acc: 0.9994 - val_loss: 0.0248 - val_acc: 0.9931
# Epoch 189/1000
#  - 1s - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0237 - val_acc: 0.9939
# Epoch 190/1000
#  - 1s - loss: 0.0056 - acc: 0.9997 - val_loss: 0.0240 - val_acc: 0.9939
# Epoch 191/1000
#  - 1s - loss: 0.0046 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 0.9939
# Epoch 192/1000
#  - 1s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 193/1000
#  - 1s - loss: 0.0052 - acc: 0.9997 - val_loss: 0.0228 - val_acc: 0.9948
# Epoch 194/1000
#  - 1s - loss: 0.0053 - acc: 0.9997 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 195/1000
#  - 1s - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0228 - val_acc: 0.9939
# Epoch 196/1000
#  - 1s - loss: 0.0060 - acc: 0.9994 - val_loss: 0.0236 - val_acc: 0.9948
# Epoch 197/1000
#  - 1s - loss: 0.0051 - acc: 0.9997 - val_loss: 0.0229 - val_acc: 0.9939
# Epoch 198/1000
#  - 1s - loss: 0.0053 - acc: 0.9994 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 199/1000
#  - 1s - loss: 0.0045 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 200/1000
#  - 1s - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9948
# Epoch 201/1000
#  - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 202/1000
#  - 1s - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 203/1000
#  - 1s - loss: 0.0049 - acc: 0.9997 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 204/1000
#  - 1s - loss: 0.0052 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 205/1000
#  - 1s - loss: 0.0047 - acc: 0.9997 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 206/1000
#  - 1s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 207/1000
#  - 1s - loss: 0.0045 - acc: 0.9997 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 208/1000
#  - 1s - loss: 0.0059 - acc: 0.9994 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 209/1000
#  - 1s - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 0.9948
# Epoch 210/1000
#  - 1s - loss: 0.0046 - acc: 0.9994 - val_loss: 0.0216 - val_acc: 0.9939
# Epoch 211/1000
#  - 1s - loss: 0.0048 - acc: 0.9997 - val_loss: 0.0239 - val_acc: 0.9939
# Epoch 212/1000
#  - 1s - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 213/1000
#  - 1s - loss: 0.0050 - acc: 0.9997 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 214/1000
#  - 1s - loss: 0.0050 - acc: 0.9997 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 215/1000
#  - 1s - loss: 0.0060 - acc: 0.9988 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 216/1000
#  - 1s - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 217/1000
#  - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 218/1000
#  - 1s - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 219/1000
#  - 1s - loss: 0.0051 - acc: 0.9994 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 220/1000
#  - 1s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 221/1000
#  - 1s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 222/1000
#  - 1s - loss: 0.0040 - acc: 0.9997 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 223/1000
#  - 1s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 224/1000
#  - 1s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 225/1000
#  - 1s - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 226/1000
#  - 1s - loss: 0.0041 - acc: 0.9997 - val_loss: 0.0232 - val_acc: 0.9939
# Epoch 227/1000
#  - 1s - loss: 0.0039 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 228/1000
#  - 1s - loss: 0.0039 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 229/1000
#  - 1s - loss: 0.0046 - acc: 0.9994 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 230/1000
#  - 1s - loss: 0.0038 - acc: 0.9997 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 231/1000
#  - 1s - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 0.9939
# Epoch 232/1000
#  - 1s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 233/1000
#  - 1s - loss: 0.0042 - acc: 0.9997 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 234/1000
#  - 1s - loss: 0.0041 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 235/1000
#  - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 236/1000
#  - 1s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 237/1000
#  - 1s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 238/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 239/1000
#  - 1s - loss: 0.0050 - acc: 0.9997 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 240/1000
#  - 1s - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 241/1000
#  - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9948
# Epoch 242/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 243/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 244/1000
#  - 1s - loss: 0.0036 - acc: 0.9997 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 245/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 246/1000
#  - 1s - loss: 0.0035 - acc: 0.9997 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 247/1000
#  - 1s - loss: 0.0040 - acc: 0.9997 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 248/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 0.9939
# Epoch 249/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 250/1000
#  - 1s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 251/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 0.9939
# Epoch 252/1000
#  - 1s - loss: 0.0040 - acc: 0.9994 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 253/1000
#  - 1s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 254/1000
#  - 1s - loss: 0.0037 - acc: 0.9994 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 255/1000
#  - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 256/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 257/1000
#  - 1s - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 258/1000
#  - 1s - loss: 0.0041 - acc: 0.9997 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 259/1000
#  - 1s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 260/1000
#  - 1s - loss: 0.0035 - acc: 1.0000 - val_loss: 0.0189 - val_acc: 0.9948
# Epoch 261/1000
#  - 1s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9948
# Epoch 262/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 263/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 264/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 265/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 266/1000
#  - 1s - loss: 0.0033 - acc: 0.9997 - val_loss: 0.0228 - val_acc: 0.9939
# Epoch 267/1000
#  - 1s - loss: 0.0037 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 268/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 0.9939
# Epoch 269/1000
#  - 1s - loss: 0.0035 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 270/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 271/1000
#  - 1s - loss: 0.0037 - acc: 0.9997 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 272/1000
#  - 1s - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 273/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 274/1000
#  - 1s - loss: 0.0038 - acc: 0.9994 - val_loss: 0.0224 - val_acc: 0.9939
# Epoch 275/1000
#  - 1s - loss: 0.0034 - acc: 0.9997 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 276/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 277/1000
#  - 1s - loss: 0.0035 - acc: 0.9997 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 278/1000
#  - 1s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 279/1000
#  - 1s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 280/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 281/1000
#  - 1s - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 282/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9939
# Epoch 283/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 284/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 285/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9939
# Epoch 286/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 287/1000
#  - 1s - loss: 0.0033 - acc: 0.9997 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 288/1000
#  - 1s - loss: 0.0036 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 289/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 290/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 291/1000
#  - 1s - loss: 0.0035 - acc: 0.9997 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 292/1000
#  - 1s - loss: 0.0038 - acc: 0.9994 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 293/1000
#  - 1s - loss: 0.0037 - acc: 0.9997 - val_loss: 0.0186 - val_acc: 0.9939
# Epoch 294/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 295/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 296/1000
#  - 1s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 297/1000
#  - 1s - loss: 0.0034 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 298/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 299/1000
#  - 1s - loss: 0.0030 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 300/1000
#  - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9939
# Epoch 301/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 302/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 303/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9948
# Epoch 304/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 305/1000
#  - 1s - loss: 0.0029 - acc: 0.9994 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 306/1000
#  - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 307/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0186 - val_acc: 0.9948
# Epoch 308/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 309/1000
#  - 1s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0186 - val_acc: 0.9948
# Epoch 310/1000
#  - 1s - loss: 0.0025 - acc: 0.9997 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 311/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 312/1000
#  - 1s - loss: 0.0028 - acc: 0.9997 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 313/1000
#  - 1s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 314/1000
#  - 1s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 315/1000
#  - 1s - loss: 0.0032 - acc: 0.9997 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 316/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 317/1000
#  - 1s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 318/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0186 - val_acc: 0.9939
# Epoch 319/1000
#  - 1s - loss: 0.0030 - acc: 0.9997 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 320/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 321/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9939
# Epoch 322/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 323/1000
#  - 1s - loss: 0.0040 - acc: 0.9997 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 324/1000
#  - 1s - loss: 0.0027 - acc: 0.9997 - val_loss: 0.0193 - val_acc: 0.9939
# Epoch 325/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 326/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 327/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0236 - val_acc: 0.9939
# Epoch 328/1000
#  - 1s - loss: 0.0026 - acc: 0.9997 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 329/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 330/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 331/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 332/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 333/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 334/1000
#  - 1s - loss: 0.0028 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 335/1000
#  - 1s - loss: 0.0029 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 336/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 337/1000
#  - 1s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9939
# Epoch 338/1000
#  - 1s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 339/1000
#  - 1s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 340/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 341/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 342/1000
#  - 1s - loss: 0.0027 - acc: 0.9997 - val_loss: 0.0260 - val_acc: 0.9931
# Epoch 343/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 0.9939
# Epoch 344/1000
#  - 1s - loss: 0.0028 - acc: 0.9997 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 345/1000
#  - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 346/1000
#  - 1s - loss: 0.0032 - acc: 0.9997 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 347/1000
#  - 1s - loss: 0.0026 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 348/1000
#  - 1s - loss: 0.0024 - acc: 0.9997 - val_loss: 0.0221 - val_acc: 0.9939
# Epoch 349/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 350/1000
#  - 1s - loss: 0.0027 - acc: 0.9997 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 351/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 352/1000
#  - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 353/1000
#  - 1s - loss: 0.0027 - acc: 0.9997 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 354/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 355/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 356/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9939
# Epoch 357/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 358/1000
#  - 1s - loss: 0.0031 - acc: 0.9994 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 359/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 360/1000
#  - 1s - loss: 0.0026 - acc: 0.9997 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 361/1000
#  - 1s - loss: 0.0022 - acc: 0.9997 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 362/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 363/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 364/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 365/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 366/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 367/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 368/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 0.9939
# Epoch 369/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 370/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 371/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 372/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 373/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 374/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 375/1000
#  - 1s - loss: 0.0029 - acc: 0.9997 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 376/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 377/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 378/1000
#  - 1s - loss: 0.0024 - acc: 0.9997 - val_loss: 0.0193 - val_acc: 0.9939
# Epoch 379/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 380/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 381/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 382/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 383/1000
#  - 1s - loss: 0.0024 - acc: 0.9997 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 384/1000
#  - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 0.9939
# Epoch 385/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 386/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 0.9939
# Epoch 387/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9939
# Epoch 388/1000
#  - 1s - loss: 0.0027 - acc: 0.9997 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 389/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 390/1000
#  - 1s - loss: 0.0029 - acc: 0.9997 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 391/1000
#  - 1s - loss: 0.0024 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 392/1000
#  - 1s - loss: 0.0030 - acc: 0.9994 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 393/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 394/1000
#  - 1s - loss: 0.0025 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 395/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 396/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 397/1000
#  - 1s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 398/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0182 - val_acc: 0.9939
# Epoch 399/1000
#  - 1s - loss: 0.0022 - acc: 0.9997 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 400/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 401/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 402/1000
#  - 1s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0222 - val_acc: 0.9948
# Epoch 403/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 404/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0190 - val_acc: 0.9939
# Epoch 405/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9939
# Epoch 406/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 407/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0187 - val_acc: 0.9939
# Epoch 408/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 409/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 410/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 411/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 412/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9939
# Epoch 413/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 414/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9939
# Epoch 415/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 416/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9939
# Epoch 417/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 418/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 419/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 420/1000
#  - 1s - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 421/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 422/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 423/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 0.9939
# Epoch 424/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 425/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0227 - val_acc: 0.9939
# Epoch 426/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 427/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 428/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 429/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 430/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 0.9939
# Epoch 431/1000
#  - 1s - loss: 0.0025 - acc: 0.9997 - val_loss: 0.0184 - val_acc: 0.9948
# Epoch 432/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 433/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 434/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 435/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9948
# Epoch 436/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 437/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 438/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 439/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 440/1000
#  - 1s - loss: 0.0027 - acc: 0.9994 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 441/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 442/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0240 - val_acc: 0.9939
# Epoch 443/1000
#  - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 444/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 445/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 0.9939
# Epoch 446/1000
#  - 1s - loss: 0.0024 - acc: 0.9997 - val_loss: 0.0239 - val_acc: 0.9939
# Epoch 447/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 448/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 449/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 450/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 451/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 452/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 453/1000
#  - 1s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 454/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 455/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 456/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 457/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 458/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 459/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 460/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 461/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 462/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 463/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 464/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 465/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 466/1000
#  - 1s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 467/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 468/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9939
# Epoch 469/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 470/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9939
# Epoch 471/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 472/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 473/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 474/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 475/1000
#  - 1s - loss: 0.0023 - acc: 0.9997 - val_loss: 0.0187 - val_acc: 0.9939
# Epoch 476/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 477/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 478/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 479/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 480/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 481/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9948
# Epoch 482/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 483/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0184 - val_acc: 0.9939
# Epoch 484/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 485/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 486/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 487/1000
#  - 1s - loss: 0.0022 - acc: 0.9997 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 488/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 489/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0224 - val_acc: 0.9939
# Epoch 490/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 491/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 492/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 493/1000
#  - 1s - loss: 0.0017 - acc: 0.9997 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 494/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 495/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 496/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 497/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 498/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 499/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9939
# Epoch 500/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 501/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 502/1000
#  - 1s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 503/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 504/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0188 - val_acc: 0.9939
# Epoch 505/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 506/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 507/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 508/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0227 - val_acc: 0.9939
# Epoch 509/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 510/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 511/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 512/1000
#  - 1s - loss: 0.0018 - acc: 0.9997 - val_loss: 0.0194 - val_acc: 0.9939
# Epoch 513/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9939
# Epoch 514/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9939
# Epoch 515/1000
#  - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9948
# Epoch 516/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 517/1000
#  - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 518/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 519/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 520/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 521/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9939
# Epoch 522/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 523/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9939
# Epoch 524/1000
#  - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9939
# Epoch 525/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9957
# Epoch 526/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9948
# Epoch 527/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9939
# Epoch 528/1000
#  - 1s - loss: 0.0018 - acc: 0.9997 - val_loss: 0.0196 - val_acc: 0.9939
# Epoch 529/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 530/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0185 - val_acc: 0.9948
# Epoch 531/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 532/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9939
# Epoch 533/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9939
# Epoch 534/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 535/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9957
# Epoch 536/1000
#  - 1s - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0207 - val_acc: 0.9939
# Epoch 537/1000
#  - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9957
# Epoch 538/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9948
# Epoch 539/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 540/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 541/1000
#  - 1s - loss: 0.0021 - acc: 0.9997 - val_loss: 0.0196 - val_acc: 0.9957
# Epoch 542/1000
#  - 1s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9939
# Epoch 543/1000
#  - 1s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9948
# Epoch 544/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 545/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9939
# Epoch 546/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 547/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 548/1000
#  - 1s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0184 - val_acc: 0.9948
# Epoch 549/1000
#  - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9957
# Epoch 550/1000
#  - 1s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9948
# Epoch 551/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9948
# Epoch 552/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 553/1000
# ...
# Epoch 824/1000
#  - 1s - loss: 7.0630e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9939
# Epoch 825/1000
#  - 1s - loss: 7.6569e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 826/1000
#  - 1s - loss: 9.9702e-04 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 827/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 828/1000
#  - 1s - loss: 8.2613e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9939
# Epoch 829/1000
#  - 1s - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0190 - val_acc: 0.9957
# Epoch 830/1000
#  - 1s - loss: 9.2727e-04 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9948
# Epoch 831/1000
#  - 1s - loss: 8.5256e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 832/1000
#  - 1s - loss: 7.2324e-04 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 833/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9939
# Epoch 834/1000
#  - 1s - loss: 7.9312e-04 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9948
# Epoch 835/1000
#  - 1s - loss: 8.2706e-04 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9957
# Epoch 836/1000
#  - 1s - loss: 7.6261e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9957
# Epoch 837/1000
#  - 1s - loss: 8.7570e-04 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 838/1000
#  - 1s - loss: 7.4468e-04 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9948
# Epoch 839/1000
#  - 1s - loss: 8.8393e-04 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9939
# Epoch 840/1000
#  - 1s - loss: 8.5203e-04 - acc: 1.0000 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 841/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 842/1000
#  - 1s - loss: 7.7438e-04 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 843/1000
#  - 1s - loss: 8.4719e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 844/1000
#  - 1s - loss: 8.6066e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 845/1000
#  - 1s - loss: 8.4492e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 846/1000
#  - 1s - loss: 6.7415e-04 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 847/1000
#  - 1s - loss: 9.0163e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 848/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 849/1000
#  - 1s - loss: 9.7585e-04 - acc: 1.0000 - val_loss: 0.0239 - val_acc: 0.9939
# Epoch 850/1000
#  - 1s - loss: 8.1569e-04 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 851/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 852/1000
#  - 1s - loss: 9.2036e-04 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9948
# Epoch 853/1000
#  - 1s - loss: 8.7379e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 854/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 855/1000
#  - 1s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 856/1000
#  - 1s - loss: 8.2283e-04 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 857/1000
#  - 1s - loss: 9.5709e-04 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 858/1000
#  - 1s - loss: 8.3284e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 859/1000
#  - 1s - loss: 6.6979e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9948
# Epoch 860/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9948
# Epoch 861/1000
#  - 1s - loss: 8.8680e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 862/1000
#  - 1s - loss: 8.1124e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 863/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 864/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 865/1000
#  - 1s - loss: 8.4138e-04 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9948
# Epoch 866/1000
#  - 1s - loss: 9.2189e-04 - acc: 1.0000 - val_loss: 0.0227 - val_acc: 0.9939
# Epoch 867/1000
#  - 1s - loss: 8.4131e-04 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 868/1000
#  - 1s - loss: 8.9696e-04 - acc: 1.0000 - val_loss: 0.0189 - val_acc: 0.9957
# Epoch 869/1000
#  - 1s - loss: 8.4741e-04 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 870/1000
#  - 1s - loss: 9.6271e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9957
# Epoch 871/1000
#  - 1s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0220 - val_acc: 0.9939
# Epoch 872/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 873/1000
#  - 1s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0187 - val_acc: 0.9948
# Epoch 874/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9948
# Epoch 875/1000
#  - 1s - loss: 8.8868e-04 - acc: 1.0000 - val_loss: 0.0185 - val_acc: 0.9948
# Epoch 876/1000
#  - 1s - loss: 6.8291e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 877/1000
#  - 1s - loss: 8.5107e-04 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 878/1000
#  - 1s - loss: 7.9258e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 879/1000
#  - 1s - loss: 7.9201e-04 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 880/1000
#  - 1s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 881/1000
#  - 1s - loss: 8.0273e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 882/1000
#  - 1s - loss: 9.0858e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9948
# Epoch 883/1000
#  - 1s - loss: 9.6903e-04 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9948
# Epoch 884/1000
#  - 1s - loss: 9.0554e-04 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 0.9939
# Epoch 885/1000
#  - 1s - loss: 7.4672e-04 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 886/1000
#  - 1s - loss: 8.5614e-04 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9948
# Epoch 887/1000
#  - 1s - loss: 8.0023e-04 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9948
# Epoch 888/1000
#  - 1s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 889/1000
#  - 1s - loss: 7.4748e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 890/1000
#  - 1s - loss: 9.4686e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 891/1000
#  - 1s - loss: 6.0593e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 892/1000
#  - 1s - loss: 8.6118e-04 - acc: 1.0000 - val_loss: 0.0233 - val_acc: 0.9939
# Epoch 893/1000
#  - 1s - loss: 7.3392e-04 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9939
# Epoch 894/1000
#  - 1s - loss: 8.8221e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9948
# Epoch 895/1000
#  - 1s - loss: 7.5782e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9948
# Epoch 896/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9939
# Epoch 897/1000
#  - 1s - loss: 8.3283e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9957
# Epoch 898/1000
#  - 1s - loss: 6.9367e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 899/1000
#  - 1s - loss: 9.7310e-04 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 900/1000
#  - 1s - loss: 7.3819e-04 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9939
# Epoch 901/1000
#  - 1s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0230 - val_acc: 0.9948
# Epoch 902/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 0.9939
# Epoch 903/1000
#  - 1s - loss: 9.8566e-04 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9948
# Epoch 904/1000
#  - 1s - loss: 8.1519e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 905/1000
#  - 1s - loss: 8.5123e-04 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 906/1000
#  - 1s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0214 - val_acc: 0.9948
# Epoch 907/1000
#  - 1s - loss: 7.3370e-04 - acc: 1.0000 - val_loss: 0.0204 - val_acc: 0.9948
# Epoch 908/1000
#  - 1s - loss: 8.8836e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 909/1000
#  - 1s - loss: 6.9269e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 910/1000
#  - 1s - loss: 9.5230e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 911/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 912/1000
#  - 1s - loss: 8.5266e-04 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9948
# Epoch 913/1000
#  - 1s - loss: 6.2083e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 914/1000
#  - 1s - loss: 5.7410e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 915/1000
#  - 1s - loss: 8.9187e-04 - acc: 0.9997 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 916/1000
#  - 1s - loss: 8.5924e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 917/1000
#  - 1s - loss: 8.4438e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9939
# Epoch 918/1000
#  - 1s - loss: 9.8455e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9948
# Epoch 919/1000
#  - 1s - loss: 8.2531e-04 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 920/1000
#  - 1s - loss: 8.7876e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 921/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 922/1000
#  - 1s - loss: 7.4558e-04 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 923/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9939
# Epoch 924/1000
#  - 1s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0252 - val_acc: 0.9948
# Epoch 925/1000
#  - 1s - loss: 8.8290e-04 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9948
# Epoch 926/1000
#  - 1s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 927/1000
#  - 1s - loss: 8.3670e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 928/1000
#  - 1s - loss: 7.0550e-04 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 929/1000
#  - 1s - loss: 7.7560e-04 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 930/1000
#  - 1s - loss: 7.1555e-04 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 931/1000
#  - 1s - loss: 8.9543e-04 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 0.9939
# Epoch 932/1000
#  - 1s - loss: 9.2263e-04 - acc: 0.9997 - val_loss: 0.0229 - val_acc: 0.9948
# Epoch 933/1000
#  - 1s - loss: 7.3434e-04 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9948
# Epoch 934/1000
#  - 1s - loss: 6.7249e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 935/1000
#  - 1s - loss: 0.0012 - acc: 0.9994 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 936/1000
#  - 1s - loss: 9.3853e-04 - acc: 1.0000 - val_loss: 0.0201 - val_acc: 0.9948
# Epoch 937/1000
#  - 1s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.0195 - val_acc: 0.9948
# Epoch 938/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0212 - val_acc: 0.9948
# Epoch 939/1000
#  - 1s - loss: 8.0808e-04 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9939
# Epoch 940/1000
#  - 1s - loss: 7.0643e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 941/1000
#  - 1s - loss: 8.4178e-04 - acc: 1.0000 - val_loss: 0.0213 - val_acc: 0.9939
# Epoch 942/1000
#  - 1s - loss: 8.9913e-04 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 0.9948
# Epoch 943/1000
#  - 1s - loss: 7.8732e-04 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 944/1000
#  - 1s - loss: 6.3566e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 945/1000
#  - 1s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 946/1000
#  - 1s - loss: 8.1753e-04 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9948
# Epoch 947/1000
#  - 1s - loss: 9.0949e-04 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9948
# Epoch 948/1000
#  - 1s - loss: 7.3578e-04 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 0.9948
# Epoch 949/1000
#  - 1s - loss: 7.6704e-04 - acc: 1.0000 - val_loss: 0.0214 - val_acc: 0.9939
# Epoch 950/1000
#  - 1s - loss: 9.4334e-04 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 951/1000
#  - 1s - loss: 6.5538e-04 - acc: 1.0000 - val_loss: 0.0214 - val_acc: 0.9948
# Epoch 952/1000
#  - 1s - loss: 7.8433e-04 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 953/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 954/1000
#  - 1s - loss: 7.1251e-04 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 0.9939
# Epoch 955/1000
#  - 1s - loss: 9.0938e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 956/1000
#  - 1s - loss: 8.3599e-04 - acc: 1.0000 - val_loss: 0.0235 - val_acc: 0.9939
# Epoch 957/1000
#  - 1s - loss: 7.5542e-04 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9948
# Epoch 958/1000
#  - 1s - loss: 8.5245e-04 - acc: 1.0000 - val_loss: 0.0197 - val_acc: 0.9948
# Epoch 959/1000
#  - 1s - loss: 7.7991e-04 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 960/1000
#  - 1s - loss: 8.8328e-04 - acc: 1.0000 - val_loss: 0.0218 - val_acc: 0.9939
# Epoch 961/1000
#  - 1s - loss: 7.6860e-04 - acc: 1.0000 - val_loss: 0.0203 - val_acc: 0.9948
# Epoch 962/1000
#  - 1s - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0209 - val_acc: 0.9948
# Epoch 963/1000
#  - 1s - loss: 7.9215e-04 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 964/1000
#  - 1s - loss: 7.7140e-04 - acc: 1.0000 - val_loss: 0.0206 - val_acc: 0.9948
# Epoch 965/1000
#  - 1s - loss: 9.8270e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9957
# Epoch 966/1000
#  - 1s - loss: 6.1577e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 967/1000
#  - 1s - loss: 8.1403e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 968/1000
#  - 1s - loss: 6.4344e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 969/1000
#  - 1s - loss: 6.3726e-04 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9948
# Epoch 970/1000
#  - 1s - loss: 8.9234e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 971/1000
#  - 1s - loss: 9.2648e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 972/1000
#  - 1s - loss: 7.4018e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 973/1000
#  - 1s - loss: 6.4100e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 974/1000
#  - 1s - loss: 8.1746e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 975/1000
#  - 1s - loss: 9.0256e-04 - acc: 0.9997 - val_loss: 0.0219 - val_acc: 0.9948
# Epoch 976/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9957
# Epoch 977/1000
#  - 1s - loss: 8.9170e-04 - acc: 1.0000 - val_loss: 0.0205 - val_acc: 0.9948
# Epoch 978/1000
#  - 1s - loss: 9.9678e-04 - acc: 1.0000 - val_loss: 0.0190 - val_acc: 0.9965
# Epoch 979/1000
#  - 1s - loss: 7.7406e-04 - acc: 1.0000 - val_loss: 0.0211 - val_acc: 0.9948
# Epoch 980/1000
#  - 1s - loss: 9.5580e-04 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9948
# Epoch 981/1000
#  - 1s - loss: 8.5742e-04 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 982/1000
#  - 1s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0217 - val_acc: 0.9948
# Epoch 983/1000
#  - 1s - loss: 7.4705e-04 - acc: 1.0000 - val_loss: 0.0196 - val_acc: 0.9957
# Epoch 984/1000
#  - 1s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0196 - val_acc: 0.9948
# Epoch 985/1000
#  - 1s - loss: 7.2049e-04 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9948
# Epoch 986/1000
#  - 1s - loss: 7.7125e-04 - acc: 1.0000 - val_loss: 0.0198 - val_acc: 0.9948
# Epoch 987/1000
#  - 1s - loss: 7.5855e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 988/1000
#  - 1s - loss: 8.9243e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 989/1000
#  - 1s - loss: 9.6763e-04 - acc: 1.0000 - val_loss: 0.0208 - val_acc: 0.9948
# Epoch 990/1000
#  - 1s - loss: 8.8744e-04 - acc: 1.0000 - val_loss: 0.0191 - val_acc: 0.9948
# Epoch 991/1000
#  - 1s - loss: 6.9435e-04 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9957
# Epoch 992/1000
#  - 1s - loss: 7.6757e-04 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9948
# Epoch 993/1000
#  - 1s - loss: 6.9257e-04 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 994/1000
#  - 1s - loss: 7.8330e-04 - acc: 1.0000 - val_loss: 0.0190 - val_acc: 0.9957
# Epoch 995/1000
#  - 1s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0210 - val_acc: 0.9939
# Epoch 996/1000
#  - 1s - loss: 7.3821e-04 - acc: 1.0000 - val_loss: 0.0199 - val_acc: 0.9948
# Epoch 997/1000
#  - 1s - loss: 6.6970e-04 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948
# Epoch 998/1000
#  - 1s - loss: 8.7430e-04 - acc: 1.0000 - val_loss: 0.0186 - val_acc: 0.9948
# Epoch 999/1000
#  - 1s - loss: 7.3096e-04 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9957
# Epoch 1000/1000
#  - 1s - loss: 9.0230e-04 - acc: 1.0000 - val_loss: 0.0193 - val_acc: 0.9948

# %%
preds = model.predict(test_data)

predictions = [i.argmax() for i in preds]
y_true = [i.argmax() for i in test_labels]
cm = confusion_matrix(y_pred=predictions, y_true=y_true)

print('Accuracy {}'.format(accuracy_score(y_true=y_true, y_pred=predictions)))
# Out:
# Accuracy 0.87

# %%
plt.rcParams["axes.grid"] = False
plt.rcParams.update({'font.size': 20})

labels = []

label = test_generator.class_indices
indexlabel = dict((value, key) for key, value in label.items())

for k,v in indexlabel.items():
    labels.append(v)

from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion Matrix')

    print(cm)
#     fig = plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
#     plt.title(title)
#     plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
#     plt.savefig('plots/3.InceptionV3-2-Private-DataSet-CM.png', bbox_inches='tight', dpi = 100) 


plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, classes=labels, title=' ')
# Out:
# Confusion Matrix
# [[21  1  0  3]
#  [ 1 22  1  1]
#  [ 1  2 22  0]
#  [ 3  0  0 22]]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
y_pred=predictions
y_pred_probabilities=y_pred

# y_pred = np.argmax(y_pred,axis = 1) 
y_actual = y_true

classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)

confusion_mtx = confusion_matrix(y_actual, y_pred) 
print(confusion_mtx)
target_names = classnames
print(classification_report(y_actual, y_pred, target_names=target_names))
# Out:
# [[21  1  0  3]
#  [ 1 22  1  1]
#  [ 1  2 22  0]
#  [ 3  0  0 22]]
#               precision    recall  f1-score   support
#
#       Benign       0.81      0.84      0.82        25
#       InSitu       0.88      0.88      0.88        25
#     Invasive       0.96      0.88      0.92        25
#       Normal       0.85      0.88      0.86        25
#
#    micro avg       0.87      0.87      0.87       100
#    macro avg       0.87      0.87      0.87       100
# weighted avg       0.87      0.87      0.87       100

# %%
total=sum(sum(cm))

sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
print('Sensitivity : ', sensitivity*100 )

Specificity = cm[1,1]/(cm[1,1]+cm[0,1])
print('Specificity : ', Specificity*100 )
# Out:
# Sensitivity :  95.45454545454545
# Specificity :  95.65217391304348

# %%
plt.style.use("seaborn-ticks")

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training Acc', 'Test Acc'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Test Loss'], loc='upper left')
plt.show()

plt.figure()
N = epochs
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")

# %%
#ROC Curve for each class
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline  
from scipy import interp
from itertools import cycle

predict_class = np.argmax(preds, axis=1)

y_pred = preds
y_pred_probabilities=y_pred

y_pred = np.argmax(y_pred,axis = 1) 
y_actual = test_generator.classes

classnames=[]
for classname in test_generator.class_indices:
    classnames.append(classname)

y_actual_binary = label_binarize(y_actual, classes=[0, 1, 2, 3])
y_pred_binary = y_pred_probabilities
n_classes=4
lw=2

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_actual_binary[:, i], y_pred_binary[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_actual_binary.ravel(), y_pred_binary.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(7, 7))


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="best")
plt.show()

# %%
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=2)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=2)


colors = cycle(['red','blue','green','yellow','orange', 'aqua', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(classnames[i], roc_auc[i]))

    
    
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-classs')
plt.legend(loc="lower right")
# plt.savefig('') 
plt.show()

# %%
y_pred_class = model.predict(test_data, verbose=1)

y_pred_class = [np.argmax(r) for r in y_pred_class]
test_y = [np.argmax(r) for r in test_labels]
# Out:
# 100/100 [==============================] - 0s 208us/step

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score, roc_auc_score, roc_curve

# Precision
print('Precision = ', precision_score(test_y, y_pred_class, average='weighted'))
# (None, 'micro', 'macro', 'weighted', 'samples')

# Recall
print('Recall = ', recall_score(test_y, y_pred_class, average='weighted'))

# f1_score
print('f1_score = ', f1_score(test_y, y_pred_class, average='weighted'))
# Out:
# Precision =  0.8725919732441472
# Recall =  0.87
# f1_score =  0.8707352941176469

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer

def multiclass_roc_auc_score(y_test, y_pred, average="weighted"):
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(y_test)

    truth = label_binarizer.transform(y_test)
    pred = label_binarizer.transform(y_pred)
    return roc_auc_score(truth, pred, average=average)
# roc_auc_score
print('roc_auc_score = ', multiclass_roc_auc_score(test_y, y_pred_class))
# Out:
# roc_auc_score =  0.9133333333333331
